# %%
# %%
# Importações
import sqlite3
import pandas as pd
from pathlib import Path

# %%
# Caminho relativo para o banco no diretório pai
db_path = Path("..") / "unidades.db"

# Conexão com o SQLite
conn = sqlite3.connect(db_path)

# Lê toda a tabela 'unidades'
df = pd.read_sql("SELECT * FROM unidades", conn)

# Fecha a conexão
conn.close()

# %%
# Exibe apenas as colunas em foco
colunas_em_foco = ['id', 'rede','nome', 'endereco','latitude', 'longitude', 'bairro_cdn', 'cidade_cdn', 'estado_cdn', 'pais_cdn']
df[colunas_em_foco].head(20)
# Out:
#     id     rede                            nome  \
# 0    1  Bluefit                        Flamengo
# 1    2  Bluefit                      Saens Peña
# 2    3  Bluefit                       Nilópolis
# 3    4  Bluefit                         Recreio
# 4    5  Bluefit       Juiz de Fora - São Mateus
# 5    6  Bluefit  São José dos Campos – Vale Sul
# 6    7  Bluefit  São José dos Campos - Aquarius
# 7    8  Bluefit                 Mogi das Cruzes
# 8    9  Bluefit                    Savassi Mall
# 9   10  Bluefit                         Guarujá
# 10  11  Bluefit                        Pimentas
# 11  12  Bluefit                        Palmares
# 12  13  Bluefit                        Santos 3
# 13  14  Bluefit                        Santos 1
# 14  15  Bluefit                        Santos 2
# 15  16  Bluefit         Shopping Pátio Iporanga
# 16  17  Bluefit                        Tambores
# 17  18  Bluefit                     São Vicente
# 18  19  Bluefit                      Aricanduva
# 19  20  Bluefit                    Emílio Ribas
#
#                                              endereco     latitude  \
# 0   Rua Senador Vergueiro, 35 Flamengo, Rio de Jan...  -22.9341605
# 1   Rua Conde de Bonfim, 422 Tijuca, Rio de Janeir...  -22.9251951
# 2     Av. Getúlio Vargas, 1336 Centro, Nilópolis - RJ  -22.8097381
# 3   Av. das Américas, 16701 Recreio dos Bandeirant...  -23.0173942
# 4   AV PRESIDENTE ITAMAR FRANCO, 2905 SAO MATEUS, ...  -21.7783807
# 5   Av. Andrômeda, 227 Jardim Satélite, São José d...  -23.2166775
# 6   Av. Cassiano Ricardo, 521 Parque Residencial A...  -23.2182487
# 7   Av. Antônio de Almeida, 100 Jd. Marica, Mogi d...   -23.512176
# 8       R. Sergipe, 1448 Savassi, Belo Horizonte - MG  -19.9393108
# 9         Av. Dom Pedro I, 2220 Enseada, Guarujá - SP  -23.9822973
# 10  Estr. Pres. Juscelino Kubitschek de Oliveira, ...   -23.455774
# 11  Av. Cristiano Machado, 5137 Palmares, Belo Hor...  -19.8697195
# 12    Av. Almirante Cochrane, 189 Embaré, Santos - SP  -23.9717678
# 13  Av. Conselheiro Nébias, 761 Boqueirão, Santos ...  -23.9680276
# 14     Av. Presidente Wilson, 21 Gonzaga, Santos - SP  -23.9686464
# 15         Av. Ana Costa, 465/67 Gonzaga, Santos - SP  -23.9648313
# 16  Av. Antônio Emmerich, 1643 Vila Cascatinha, Sã...   -23.951428
# 17     Praça da Bandeira, 80 Centro, São Vicente - SP  -23.9642138
# 18  Av. Rio das Pedras, 1306 Jardim Aricanduva, Sã...  -23.5664716
# 19  R. Dr. José Maurício de Oliveira, 24 Gopouva, ...  -23.4662968
#
#       longitude                bairro_cdn           cidade_cdn  \
# 0   -43.1757575                  Flamengo       Rio de Janeiro
# 1   -43.2346116                    Tijuca       Rio de Janeiro
# 2   -43.4166488                    Centro            Nilópolis
# 3   -43.4762191  Recreio dos Bandeirantes       Rio de Janeiro
# 4   -43.3587724                São Mateus         Juiz de Fora
# 5   -45.8926807           Jardim Satélite  São José dos Campos
# 6   -45.9099854           Jardim Alvorada  São José dos Campos
# 7   -46.1809037             Jardim Marica      Mogi das Cruzes
# 8   -43.9387744              Funcionários       Belo Horizonte
# 9   -46.2301588             Jardim Belmar              Guarujá
# 10  -46.4093518          Jardim Albertina            Guarulhos
# 11  -43.9283746               Vila Suzana       Belo Horizonte
# 12  -46.3106119                    Embaré               Santos
# 13  -46.3234583                 Boqueirão               Santos
# 14  -46.3352031               José Menino               Santos
# 15   -46.332394                   Gonzaga               Santos
# 16  -46.3740539           Vila Cascatinha          São Vicente
# 17  -46.3831424                    Centro          São Vicente
# 18  -46.5120321            Vila Antonieta            São Paulo
# 19  -46.5447634                   Gopouva            Guarulhos
#
#         estado_cdn pais_cdn
# 0   Rio de Janeiro   Brazil
# 1   Rio de Janeiro   Brazil
# 2   Rio de Janeiro   Brazil
# 3   Rio de Janeiro   Brazil
# 4     Minas Gerais   Brazil
# 5        São Paulo   Brazil
# 6        São Paulo   Brazil
# 7        São Paulo   Brazil
# 8     Minas Gerais   Brazil
# 9        São Paulo   Brazil
# 10       São Paulo   Brazil
# 11    Minas Gerais   Brazil
# 12       São Paulo   Brazil
# 13       São Paulo   Brazil
# 14       São Paulo   Brazil
# 15       São Paulo   Brazil
# 16       São Paulo   Brazil
# 17       São Paulo   Brazil
# 18       São Paulo   Brazil
# 19       São Paulo   Brazil
